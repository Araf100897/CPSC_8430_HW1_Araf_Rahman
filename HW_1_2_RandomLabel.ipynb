# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from torch.autograd import Variable

# %%
if torch.cuda.is_available():
   DEVICE = torch.device("cuda")
else:
   DEVICE = torch.device("cpu")

print(DEVICE)
# Out:
# cpu

# %%
torch.manual_seed(1)

# %%
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.Compose([transforms.ToTensor(),]),download=True,)


test_dataset = torchvision.datasets.MNIST(root='./data',train=False,transform=transforms.Compose([transforms.ToTensor(),]))

print("train_dataset size:", len(train_dataset),"\ntest_dataset size:", len(test_dataset))
# Out:
# train_dataset size: 60000
# test_dataset size: 10000

# %%
randomLabels = torch.tensor(np.random.randint(0, 10, (len(train_dataset)),))
train_dataset.targets = randomLabels


MNIST_train_loader = torch.utils.data.DataLoader(dataset=train_dataset,batch_size=100,shuffle=True)

MNIST_test_loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size=100,shuffle=False)

samples = iter(MNIST_train_loader)
sample_data, sample_targets = next(samples)

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.imshow(sample_data[i][0], cmap='gray')
    plt.title("Actual Val: {}".format(sample_targets[i]))
    plt.xticks([])
    plt.yticks([])
plt.show()

# %%
class RMNIST(nn.Module):
    def __init__(self):
        super(RMNIST, self).__init__()
        
        self.fc1 = nn.Linear(784, 500)
        self.fc2 = nn.Linear(500, 10)
        

    def forward(self, x):


        x = x.view(x.size()[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

def train(model, optimizer, epoch, MNIST_train_loader, interval):
    model.train()
    loss_fn = torch.nn.CrossEntropyLoss()
    n_correct = 0
    n_samples = 0
    for i, (data, target) in enumerate(MNIST_train_loader):
        
         
        data, target = Variable(data), Variable(target)
        
        optimizer.zero_grad()


        prediction = model(data)
        loss = loss_fn(prediction, target)
        

        loss.backward()
        
        optimizer.step()

        _, predicted = torch.max(prediction.data, 1)
        n_samples += target.size(0)
        n_correct += (predicted == target).sum().item()
        acc = 100.0 * n_correct / n_samples
        
        
        if i % interval == 0:
            print (f'Train Log:Epoch: {epoch}, Step [{i+1}/{len(MNIST_train_loader.dataset)}], TrainLoss: {loss.item():.4f}')
    return loss.data, round(acc,2)

# %%
def test(model, epoch, MNIST_test_loader):
    test_load = MNIST_test_loader
    model.eval()
    n_correct = 0
    n_samples = 0
    testLoss = 0
    count = 0
    
    with torch.no_grad():
        for images, labels in test_load:
            images, labels = Variable(images),Variable(labels)
    
            prediction = model(images)
            testLoss += loss_func(prediction,labels).item()
           
            _,predicted = torch.max(prediction.data, 1)
            n_samples += labels.size(0)
            count += 1
            n_correct += (predicted == labels).sum().item()
    
        Test_loss = testLoss/count
        netTest_acc1 = 100.0 * n_correct / n_samples
        print(f'Accuracy of the network on the test images: {netTest_acc1}% & Test Loss: {Test_loss}')
    return netTest_acc1, Test_loss



rmnist = RMNIST()
loss_func = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(rmnist.parameters(), lr=0.0001)

a=[]
for i in rmnist.parameters():
    a.append(torch.numel(i))
print('Total no of parameters in Model 1:', np.sum(a),)

train_loss_arr = []

test_loss_arr = []

epochArr = []
epochs = 1000
interval = 500
for epoch in range(1, epochs + 1):
    epochArr.append(epoch)
    loss, acc = train(rmnist, optimizer, epoch, MNIST_train_loader, interval)
    train_loss_arr.append(loss.detach().numpy())
    testAcc,testloss = test(rmnist, epoch, MNIST_test_loader)
    test_loss_arr.append(testloss)

    


plt.plot(epochArr,train_loss_arr,color="red")
plt.plot(epochArr,test_loss_arr,color="Blue")
plt.legend(['Train Loss','Test Loss'],loc="upper right")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Random labels train vs test loss",color = "green")

plt.show()
# Out:
# Total no of parameters in Model 1: 397510
# Train Log:Epoch: 1, Step [1/60000], TrainLoss: 2.3073
# Train Log:Epoch: 1, Step [501/60000], TrainLoss: 2.3045
# Accuracy of the network on the test images: 12.42% & Test Loss: 2.3023187589645384
# Train Log:Epoch: 2, Step [1/60000], TrainLoss: 2.3007
# Train Log:Epoch: 2, Step [501/60000], TrainLoss: 2.2990
# Accuracy of the network on the test images: 13.3% & Test Loss: 2.29012020111084
# Train Log:Epoch: 3, Step [1/60000], TrainLoss: 2.3070
# Train Log:Epoch: 3, Step [501/60000], TrainLoss: 2.3126
# Accuracy of the network on the test images: 12.69% & Test Loss: 2.3024425172805785
# Train Log:Epoch: 4, Step [1/60000], TrainLoss: 2.2940
# Train Log:Epoch: 4, Step [501/60000], TrainLoss: 2.2815
# Accuracy of the network on the test images: 11.95% & Test Loss: 2.3079366993904116
# Train Log:Epoch: 5, Step [1/60000], TrainLoss: 2.2894
# Train Log:Epoch: 5, Step [501/60000], TrainLoss: 2.3042
# Accuracy of the network on the test images: 9.48% & Test Loss: 2.3068646454811095
# Train Log:Epoch: 6, Step [1/60000], TrainLoss: 2.2949
# Train Log:Epoch: 6, Step [501/60000], TrainLoss: 2.2924
# Accuracy of the network on the test images: 11.91% & Test Loss: 2.312661597728729
# Train Log:Epoch: 7, Step [1/60000], TrainLoss: 2.2784
# Train Log:Epoch: 7, Step [501/60000], TrainLoss: 2.2911
# Accuracy of the network on the test images: 12.72% & Test Loss: 2.31360200881958
# Train Log:Epoch: 8, Step [1/60000], TrainLoss: 2.2872
# Train Log:Epoch: 8, Step [501/60000], TrainLoss: 2.2790
# Accuracy of the network on the test images: 13.88% & Test Loss: 2.3032222986221313
# Train Log:Epoch: 9, Step [1/60000], TrainLoss: 2.2748
# Train Log:Epoch: 9, Step [501/60000], TrainLoss: 2.2928
# Accuracy of the network on the test images: 10.82% & Test Loss: 2.3046237349510195
# Train Log:Epoch: 10, Step [1/60000], TrainLoss: 2.2459
# Train Log:Epoch: 10, Step [501/60000], TrainLoss: 2.2522
# Accuracy of the network on the test images: 10.9% & Test Loss: 2.3218971514701843
# Train Log:Epoch: 11, Step [1/60000], TrainLoss: 2.3028
# Train Log:Epoch: 11, Step [501/60000], TrainLoss: 2.2482
# Accuracy of the network on the test images: 11.78% & Test Loss: 2.314118568897247
# Train Log:Epoch: 12, Step [1/60000], TrainLoss: 2.2309
# Train Log:Epoch: 12, Step [501/60000], TrainLoss: 2.2678
# Accuracy of the network on the test images: 11.36% & Test Loss: 2.316606414318085
# Train Log:Epoch: 13, Step [1/60000], TrainLoss: 2.2110
# Train Log:Epoch: 13, Step [501/60000], TrainLoss: 2.2308
# Accuracy of the network on the test images: 13.46% & Test Loss: 2.313979706764221
# Train Log:Epoch: 14, Step [1/60000], TrainLoss: 2.2524
# Train Log:Epoch: 14, Step [501/60000], TrainLoss: 2.2546
# Accuracy of the network on the test images: 12.95% & Test Loss: 2.3058685278892517
# Train Log:Epoch: 15, Step [1/60000], TrainLoss: 2.2728
# Train Log:Epoch: 15, Step [501/60000], TrainLoss: 2.3015
# Accuracy of the network on the test images: 12.86% & Test Loss: 2.325033812522888
# Train Log:Epoch: 16, Step [1/60000], TrainLoss: 2.2136
# Train Log:Epoch: 16, Step [501/60000], TrainLoss: 2.2142
# Accuracy of the network on the test images: 12.68% & Test Loss: 2.3204325342178347
# Train Log:Epoch: 17, Step [1/60000], TrainLoss: 2.2051
# Train Log:Epoch: 17, Step [501/60000], TrainLoss: 2.2539
# Accuracy of the network on the test images: 11.15% & Test Loss: 2.3352950549125673
# Train Log:Epoch: 18, Step [1/60000], TrainLoss: 2.1583
# Train Log:Epoch: 18, Step [501/60000], TrainLoss: 2.1982
# Accuracy of the network on the test images: 11.51% & Test Loss: 2.326534955501556
# Train Log:Epoch: 19, Step [1/60000], TrainLoss: 2.2042
# Train Log:Epoch: 19, Step [501/60000], TrainLoss: 2.1932
# Accuracy of the network on the test images: 9.63% & Test Loss: 2.3419427108764648
# Train Log:Epoch: 20, Step [1/60000], TrainLoss: 2.1733
# Train Log:Epoch: 20, Step [501/60000], TrainLoss: 2.2056
# Accuracy of the network on the test images: 10.19% & Test Loss: 2.3464034247398375
# Train Log:Epoch: 21, Step [1/60000], TrainLoss: 2.1758
# Train Log:Epoch: 21, Step [501/60000], TrainLoss: 2.1772
# Accuracy of the network on the test images: 11.15% & Test Loss: 2.351935956478119
# Train Log:Epoch: 22, Step [1/60000], TrainLoss: 2.1744
# Train Log:Epoch: 22, Step [501/60000], TrainLoss: 2.1258
# Accuracy of the network on the test images: 12.13% & Test Loss: 2.3348648977279662
# Train Log:Epoch: 23, Step [1/60000], TrainLoss: 2.1621
# Train Log:Epoch: 23, Step [501/60000], TrainLoss: 2.1910
# Accuracy of the network on the test images: 10.95% & Test Loss: 2.365022592544556
# Train Log:Epoch: 24, Step [1/60000], TrainLoss: 2.2368
# Train Log:Epoch: 24, Step [501/60000], TrainLoss: 2.1767
# Accuracy of the network on the test images: 8.85% & Test Loss: 2.376369876861572
# Train Log:Epoch: 25, Step [1/60000], TrainLoss: 2.1596
# Train Log:Epoch: 25, Step [501/60000], TrainLoss: 2.1651
# Accuracy of the network on the test images: 11.79% & Test Loss: 2.3462094402313234
# Train Log:Epoch: 26, Step [1/60000], TrainLoss: 2.1395
# Train Log:Epoch: 26, Step [501/60000], TrainLoss: 2.1897
# Accuracy of the network on the test images: 10.57% & Test Loss: 2.3706463027000426
# Train Log:Epoch: 27, Step [1/60000], TrainLoss: 2.0638
# Train Log:Epoch: 27, Step [501/60000], TrainLoss: 2.2182
# Accuracy of the network on the test images: 10.54% & Test Loss: 2.360385763645172
# Train Log:Epoch: 28, Step [1/60000], TrainLoss: 2.1395
# Train Log:Epoch: 28, Step [501/60000], TrainLoss: 2.1752
# Accuracy of the network on the test images: 10.92% & Test Loss: 2.361168532371521
# Train Log:Epoch: 29, Step [1/60000], TrainLoss: 2.1641
# Train Log:Epoch: 29, Step [501/60000], TrainLoss: 2.1852
# Accuracy of the network on the test images: 11.06% & Test Loss: 2.3564204120635988
# Train Log:Epoch: 30, Step [1/60000], TrainLoss: 2.1330
# Train Log:Epoch: 30, Step [501/60000], TrainLoss: 2.1390
# Accuracy of the network on the test images: 9.92% & Test Loss: 2.3713455390930176
# Train Log:Epoch: 31, Step [1/60000], TrainLoss: 2.0981
# Train Log:Epoch: 31, Step [501/60000], TrainLoss: 2.0842
# Accuracy of the network on the test images: 11.57% & Test Loss: 2.3814794421195984
# Train Log:Epoch: 32, Step [1/60000], TrainLoss: 2.1148
# Train Log:Epoch: 32, Step [501/60000], TrainLoss: 2.1489
# Accuracy of the network on the test images: 11.41% & Test Loss: 2.365266032218933
# Train Log:Epoch: 33, Step [1/60000], TrainLoss: 2.0862
# Train Log:Epoch: 33, Step [501/60000], TrainLoss: 2.1386
# Accuracy of the network on the test images: 9.09% & Test Loss: 2.398096010684967
# Train Log:Epoch: 34, Step [1/60000], TrainLoss: 2.0779
# Train Log:Epoch: 34, Step [501/60000], TrainLoss: 2.0773
# Accuracy of the network on the test images: 11.69% & Test Loss: 2.3647610211372374
# Train Log:Epoch: 35, Step [1/60000], TrainLoss: 2.1214
# Train Log:Epoch: 35, Step [501/60000], TrainLoss: 2.1625
# Accuracy of the network on the test images: 11.01% & Test Loss: 2.3998153614997864
# Train Log:Epoch: 36, Step [1/60000], TrainLoss: 2.0646
# Train Log:Epoch: 36, Step [501/60000], TrainLoss: 2.0250
# Accuracy of the network on the test images: 11.71% & Test Loss: 2.394359233379364
# Train Log:Epoch: 37, Step [1/60000], TrainLoss: 2.0729
# Train Log:Epoch: 37, Step [501/60000], TrainLoss: 2.0238
# Accuracy of the network on the test images: 10.02% & Test Loss: 2.4197473192214964
# Train Log:Epoch: 38, Step [1/60000], TrainLoss: 2.1001
# Train Log:Epoch: 38, Step [501/60000], TrainLoss: 2.0838
# Accuracy of the network on the test images: 10.71% & Test Loss: 2.40039933681488
# Train Log:Epoch: 39, Step [1/60000], TrainLoss: 2.0059
# Train Log:Epoch: 39, Step [501/60000], TrainLoss: 2.0966
# Accuracy of the network on the test images: 9.07% & Test Loss: 2.4324570298194885
# Train Log:Epoch: 40, Step [1/60000], TrainLoss: 2.0530
# Train Log:Epoch: 40, Step [501/60000], TrainLoss: 1.9846
# Accuracy of the network on the test images: 10.73% & Test Loss: 2.418934614658356
# Train Log:Epoch: 41, Step [1/60000], TrainLoss: 2.1229
# Train Log:Epoch: 41, Step [501/60000], TrainLoss: 2.0810
# Accuracy of the network on the test images: 10.42% & Test Loss: 2.4240607810020447
# Train Log:Epoch: 42, Step [1/60000], TrainLoss: 2.0565
# Train Log:Epoch: 42, Step [501/60000], TrainLoss: 2.0537
# Accuracy of the network on the test images: 9.66% & Test Loss: 2.4264864468574525
# Train Log:Epoch: 43, Step [1/60000], TrainLoss: 1.9001
# Train Log:Epoch: 43, Step [501/60000], TrainLoss: 2.0418
# Accuracy of the network on the test images: 8.29% & Test Loss: 2.4555087971687315
# Train Log:Epoch: 44, Step [1/60000], TrainLoss: 2.0062
# Train Log:Epoch: 44, Step [501/60000], TrainLoss: 2.0432
# Accuracy of the network on the test images: 10.52% & Test Loss: 2.4191092658042908
# Train Log:Epoch: 45, Step [1/60000], TrainLoss: 2.0433
# Train Log:Epoch: 45, Step [501/60000], TrainLoss: 2.0606
# Accuracy of the network on the test images: 11.97% & Test Loss: 2.4255644559860228
# Train Log:Epoch: 46, Step [1/60000], TrainLoss: 2.0862
# Train Log:Epoch: 46, Step [501/60000], TrainLoss: 2.0228
# Accuracy of the network on the test images: 9.34% & Test Loss: 2.4587769961357115
# Train Log:Epoch: 47, Step [1/60000], TrainLoss: 1.9421
# Train Log:Epoch: 47, Step [501/60000], TrainLoss: 1.9366
# Accuracy of the network on the test images: 8.93% & Test Loss: 2.4650925254821776
# Train Log:Epoch: 48, Step [1/60000], TrainLoss: 1.9370
# Train Log:Epoch: 48, Step [501/60000], TrainLoss: 2.0173
# Accuracy of the network on the test images: 10.35% & Test Loss: 2.429992625713348
# Train Log:Epoch: 49, Step [1/60000], TrainLoss: 2.0190
# Train Log:Epoch: 49, Step [501/60000], TrainLoss: 1.9707
# Accuracy of the network on the test images: 11.42% & Test Loss: 2.427398045063019
# Train Log:Epoch: 50, Step [1/60000], TrainLoss: 1.8326
# Train Log:Epoch: 50, Step [501/60000], TrainLoss: 1.9774
# Accuracy of the network on the test images: 9.77% & Test Loss: 2.461876745223999
# Train Log:Epoch: 51, Step [1/60000], TrainLoss: 1.9694
# Train Log:Epoch: 51, Step [501/60000], TrainLoss: 1.9661
# Accuracy of the network on the test images: 9.26% & Test Loss: 2.475549008846283
# Train Log:Epoch: 52, Step [1/60000], TrainLoss: 1.9350
# Train Log:Epoch: 52, Step [501/60000], TrainLoss: 2.0530
# Accuracy of the network on the test images: 10.2% & Test Loss: 2.472963020801544
# Train Log:Epoch: 53, Step [1/60000], TrainLoss: 1.9744
# Train Log:Epoch: 53, Step [501/60000], TrainLoss: 1.9678
# Accuracy of the network on the test images: 12.27% & Test Loss: 2.4436880683898927
# Train Log:Epoch: 54, Step [1/60000], TrainLoss: 1.9300
# Train Log:Epoch: 54, Step [501/60000], TrainLoss: 1.9016
# Accuracy of the network on the test images: 10.31% & Test Loss: 2.4575529289245606
# Train Log:Epoch: 55, Step [1/60000], TrainLoss: 1.7900
# Train Log:Epoch: 55, Step [501/60000], TrainLoss: 1.9221
# Accuracy of the network on the test images: 9.9% & Test Loss: 2.4827597332000733
# Train Log:Epoch: 56, Step [1/60000], TrainLoss: 1.8313
# Train Log:Epoch: 56, Step [501/60000], TrainLoss: 1.9702
# Accuracy of the network on the test images: 10.41% & Test Loss: 2.480495934486389
# Train Log:Epoch: 57, Step [1/60000], TrainLoss: 1.9977
# Train Log:Epoch: 57, Step [501/60000], TrainLoss: 1.9175
# Accuracy of the network on the test images: 10.2% & Test Loss: 2.4908644485473634
# Train Log:Epoch: 58, Step [1/60000], TrainLoss: 1.8654
# Train Log:Epoch: 58, Step [501/60000], TrainLoss: 1.8733
# Accuracy of the network on the test images: 10.02% & Test Loss: 2.5170592784881594
# Train Log:Epoch: 59, Step [1/60000], TrainLoss: 1.8977
# Train Log:Epoch: 59, Step [501/60000], TrainLoss: 1.9447
# Accuracy of the network on the test images: 10.21% & Test Loss: 2.4586234092712402
# Train Log:Epoch: 60, Step [1/60000], TrainLoss: 1.8517
# Train Log:Epoch: 60, Step [501/60000], TrainLoss: 1.9048
# Accuracy of the network on the test images: 11.46% & Test Loss: 2.4825703072547913
# Train Log:Epoch: 61, Step [1/60000], TrainLoss: 1.9556
# Train Log:Epoch: 61, Step [501/60000], TrainLoss: 1.8523
# Accuracy of the network on the test images: 11.35% & Test Loss: 2.483692481517792
# Train Log:Epoch: 62, Step [1/60000], TrainLoss: 1.8758
# Train Log:Epoch: 62, Step [501/60000], TrainLoss: 1.9810
# Accuracy of the network on the test images: 9.85% & Test Loss: 2.508651795387268
# Train Log:Epoch: 63, Step [1/60000], TrainLoss: 1.8586
# Train Log:Epoch: 63, Step [501/60000], TrainLoss: 1.7934
# Accuracy of the network on the test images: 9.71% & Test Loss: 2.541157138347626
# Train Log:Epoch: 64, Step [1/60000], TrainLoss: 1.8926
# Train Log:Epoch: 64, Step [501/60000], TrainLoss: 1.8880
# Accuracy of the network on the test images: 9.46% & Test Loss: 2.5376872205734253
# Train Log:Epoch: 65, Step [1/60000], TrainLoss: 1.8404
# Train Log:Epoch: 65, Step [501/60000], TrainLoss: 1.8632
# Accuracy of the network on the test images: 9.6% & Test Loss: 2.5312370538711546
# Train Log:Epoch: 66, Step [1/60000], TrainLoss: 1.7844
# Train Log:Epoch: 66, Step [501/60000], TrainLoss: 1.7546
# Accuracy of the network on the test images: 9.91% & Test Loss: 2.545409471988678
# Train Log:Epoch: 67, Step [1/60000], TrainLoss: 1.7475
# Train Log:Epoch: 67, Step [501/60000], TrainLoss: 1.8137
# Accuracy of the network on the test images: 8.9% & Test Loss: 2.560663924217224
# Train Log:Epoch: 68, Step [1/60000], TrainLoss: 1.8147
# Train Log:Epoch: 68, Step [501/60000], TrainLoss: 1.9255
# Accuracy of the network on the test images: 9.8% & Test Loss: 2.530001184940338
# Train Log:Epoch: 69, Step [1/60000], TrainLoss: 1.8183
# Train Log:Epoch: 69, Step [501/60000], TrainLoss: 1.8943
# Accuracy of the network on the test images: 11.64% & Test Loss: 2.477577805519104
# Train Log:Epoch: 70, Step [1/60000], TrainLoss: 1.6983
# Train Log:Epoch: 70, Step [501/60000], TrainLoss: 1.9860
# Accuracy of the network on the test images: 9.5% & Test Loss: 2.555010526180267
# Train Log:Epoch: 71, Step [1/60000], TrainLoss: 1.7524
# Train Log:Epoch: 71, Step [501/60000], TrainLoss: 1.7805
# Accuracy of the network on the test images: 9.76% & Test Loss: 2.54501927614212
# Train Log:Epoch: 72, Step [1/60000], TrainLoss: 1.8518
# Train Log:Epoch: 72, Step [501/60000], TrainLoss: 1.8144
# Accuracy of the network on the test images: 10.79% & Test Loss: 2.5392006492614745
# Train Log:Epoch: 73, Step [1/60000], TrainLoss: 1.9073
# Train Log:Epoch: 73, Step [501/60000], TrainLoss: 1.8314
# Accuracy of the network on the test images: 10.63% & Test Loss: 2.5486787223815917
# Train Log:Epoch: 74, Step [1/60000], TrainLoss: 1.8584
# Train Log:Epoch: 74, Step [501/60000], TrainLoss: 1.9125
# Accuracy of the network on the test images: 9.0% & Test Loss: 2.5893673396110533
# Train Log:Epoch: 75, Step [1/60000], TrainLoss: 1.8407
# Train Log:Epoch: 75, Step [501/60000], TrainLoss: 1.7925
# Accuracy of the network on the test images: 10.56% & Test Loss: 2.5621615481376647
# Train Log:Epoch: 76, Step [1/60000], TrainLoss: 1.8708
# Train Log:Epoch: 76, Step [501/60000], TrainLoss: 1.8644
# Accuracy of the network on the test images: 9.53% & Test Loss: 2.586244821548462
# Train Log:Epoch: 77, Step [1/60000], TrainLoss: 1.7097
# Train Log:Epoch: 77, Step [501/60000], TrainLoss: 1.7812
# Accuracy of the network on the test images: 11.01% & Test Loss: 2.54674192905426
# Train Log:Epoch: 78, Step [1/60000], TrainLoss: 1.7722
# Train Log:Epoch: 78, Step [501/60000], TrainLoss: 1.8378
# Accuracy of the network on the test images: 10.32% & Test Loss: 2.5463116931915284
# Train Log:Epoch: 79, Step [1/60000], TrainLoss: 1.7869
# Train Log:Epoch: 79, Step [501/60000], TrainLoss: 1.7383
# Accuracy of the network on the test images: 10.7% & Test Loss: 2.576968746185303
# Train Log:Epoch: 80, Step [1/60000], TrainLoss: 1.7255
# Train Log:Epoch: 80, Step [501/60000], TrainLoss: 1.8226
# Accuracy of the network on the test images: 10.66% & Test Loss: 2.579260311126709
# Train Log:Epoch: 81, Step [1/60000], TrainLoss: 1.8178
# Train Log:Epoch: 81, Step [501/60000], TrainLoss: 1.7186
# Accuracy of the network on the test images: 9.94% & Test Loss: 2.597967760562897
# Train Log:Epoch: 82, Step [1/60000], TrainLoss: 1.6820
# Train Log:Epoch: 82, Step [501/60000], TrainLoss: 1.9433
# Accuracy of the network on the test images: 10.06% & Test Loss: 2.5809576439857485
# Train Log:Epoch: 83, Step [1/60000], TrainLoss: 1.7907
# Train Log:Epoch: 83, Step [501/60000], TrainLoss: 1.6975
# Accuracy of the network on the test images: 10.5% & Test Loss: 2.5950913643836975
# Train Log:Epoch: 84, Step [1/60000], TrainLoss: 1.6753
# Train Log:Epoch: 84, Step [501/60000], TrainLoss: 1.7579
# Accuracy of the network on the test images: 10.38% & Test Loss: 2.572415602207184
# Train Log:Epoch: 85, Step [1/60000], TrainLoss: 1.7379
# Train Log:Epoch: 85, Step [501/60000], TrainLoss: 1.7540
# Accuracy of the network on the test images: 9.96% & Test Loss: 2.597977819442749
# Train Log:Epoch: 86, Step [1/60000], TrainLoss: 1.7159
# Train Log:Epoch: 86, Step [501/60000], TrainLoss: 1.7442
# Accuracy of the network on the test images: 8.93% & Test Loss: 2.6523207211494446
# Train Log:Epoch: 87, Step [1/60000], TrainLoss: 1.7115
# Train Log:Epoch: 87, Step [501/60000], TrainLoss: 1.7413
# Accuracy of the network on the test images: 10.71% & Test Loss: 2.5997732210159303
# Train Log:Epoch: 88, Step [1/60000], TrainLoss: 1.6545
# Train Log:Epoch: 88, Step [501/60000], TrainLoss: 1.7484
# Accuracy of the network on the test images: 10.82% & Test Loss: 2.5989957880973815
# Train Log:Epoch: 89, Step [1/60000], TrainLoss: 1.6831
# Train Log:Epoch: 89, Step [501/60000], TrainLoss: 1.7825
# Accuracy of the network on the test images: 10.27% & Test Loss: 2.638152401447296
# Train Log:Epoch: 90, Step [1/60000], TrainLoss: 1.6483
# Train Log:Epoch: 90, Step [501/60000], TrainLoss: 1.6978
# Accuracy of the network on the test images: 10.59% & Test Loss: 2.61574955701828
# Train Log:Epoch: 91, Step [1/60000], TrainLoss: 1.7531
# Train Log:Epoch: 91, Step [501/60000], TrainLoss: 1.7501
# Accuracy of the network on the test images: 8.63% & Test Loss: 2.6862561464309693
# Train Log:Epoch: 92, Step [1/60000], TrainLoss: 1.7768
# Train Log:Epoch: 92, Step [501/60000], TrainLoss: 1.7817
# Accuracy of the network on the test images: 10.82% & Test Loss: 2.6195749950408938
# Train Log:Epoch: 93, Step [1/60000], TrainLoss: 1.8174
# Train Log:Epoch: 93, Step [501/60000], TrainLoss: 1.6787
# Accuracy of the network on the test images: 11.49% & Test Loss: 2.6319199657440184
# Train Log:Epoch: 94, Step [1/60000], TrainLoss: 1.7283
# Train Log:Epoch: 94, Step [501/60000], TrainLoss: 1.8364
# Accuracy of the network on the test images: 10.29% & Test Loss: 2.621419224739075
# Train Log:Epoch: 95, Step [1/60000], TrainLoss: 1.7380
# Train Log:Epoch: 95, Step [501/60000], TrainLoss: 1.7264
# Accuracy of the network on the test images: 10.6% & Test Loss: 2.6555347061157226
# Train Log:Epoch: 96, Step [1/60000], TrainLoss: 1.6884
# Train Log:Epoch: 96, Step [501/60000], TrainLoss: 1.7781
# Accuracy of the network on the test images: 10.45% & Test Loss: 2.659759421348572
# Train Log:Epoch: 97, Step [1/60000], TrainLoss: 1.6506
# Train Log:Epoch: 97, Step [501/60000], TrainLoss: 1.7569
# Accuracy of the network on the test images: 9.53% & Test Loss: 2.6928868889808655
# Train Log:Epoch: 98, Step [1/60000], TrainLoss: 1.6407
# Train Log:Epoch: 98, Step [501/60000], TrainLoss: 1.7158
# Accuracy of the network on the test images: 9.95% & Test Loss: 2.6856587409973143
# Train Log:Epoch: 99, Step [1/60000], TrainLoss: 1.6900
# Train Log:Epoch: 99, Step [501/60000], TrainLoss: 1.6287
# Accuracy of the network on the test images: 9.72% & Test Loss: 2.686682097911835
# Train Log:Epoch: 100, Step [1/60000], TrainLoss: 1.7411
# Train Log:Epoch: 100, Step [501/60000], TrainLoss: 1.6340
# Accuracy of the network on the test images: 10.69% & Test Loss: 2.6566067719459534
# Train Log:Epoch: 101, Step [1/60000], TrainLoss: 1.5352
# Train Log:Epoch: 101, Step [501/60000], TrainLoss: 1.6778
# Accuracy of the network on the test images: 10.3% & Test Loss: 2.7072040128707884
# Train Log:Epoch: 102, Step [1/60000], TrainLoss: 1.5157
# Train Log:Epoch: 102, Step [501/60000], TrainLoss: 1.6680
# Accuracy of the network on the test images: 9.36% & Test Loss: 2.7221631598472595
# Train Log:Epoch: 103, Step [1/60000], TrainLoss: 1.5910
# Train Log:Epoch: 103, Step [501/60000], TrainLoss: 1.6448
# Accuracy of the network on the test images: 9.78% & Test Loss: 2.728224380016327
# Train Log:Epoch: 104, Step [1/60000], TrainLoss: 1.5776
# Train Log:Epoch: 104, Step [501/60000], TrainLoss: 1.7799
# Accuracy of the network on the test images: 9.58% & Test Loss: 2.708252749443054
# Train Log:Epoch: 105, Step [1/60000], TrainLoss: 1.6406
# Train Log:Epoch: 105, Step [501/60000], TrainLoss: 1.6783
# Accuracy of the network on the test images: 10.18% & Test Loss: 2.6890606546401976
# Train Log:Epoch: 106, Step [1/60000], TrainLoss: 1.5629
# Train Log:Epoch: 106, Step [501/60000], TrainLoss: 1.5983
# Accuracy of the network on the test images: 10.15% & Test Loss: 2.7401036977767945
# Train Log:Epoch: 107, Step [1/60000], TrainLoss: 1.5087
# Train Log:Epoch: 107, Step [501/60000], TrainLoss: 1.7735
# Accuracy of the network on the test images: 10.42% & Test Loss: 2.745143256187439
# Train Log:Epoch: 108, Step [1/60000], TrainLoss: 1.6098
# Train Log:Epoch: 108, Step [501/60000], TrainLoss: 1.6046
# Accuracy of the network on the test images: 9.43% & Test Loss: 2.7391217947006226
# Train Log:Epoch: 109, Step [1/60000], TrainLoss: 1.6509
# Train Log:Epoch: 109, Step [501/60000], TrainLoss: 1.6778
# Accuracy of the network on the test images: 9.32% & Test Loss: 2.746857807636261
# Train Log:Epoch: 110, Step [1/60000], TrainLoss: 1.4839
# Train Log:Epoch: 110, Step [501/60000], TrainLoss: 1.6999
# Accuracy of the network on the test images: 9.03% & Test Loss: 2.751965894699097
# Train Log:Epoch: 111, Step [1/60000], TrainLoss: 1.5381
# Train Log:Epoch: 111, Step [501/60000], TrainLoss: 1.7479
# Accuracy of the network on the test images: 10.47% & Test Loss: 2.7534520268440246
# Train Log:Epoch: 112, Step [1/60000], TrainLoss: 1.5720
# Train Log:Epoch: 112, Step [501/60000], TrainLoss: 1.5047
# Accuracy of the network on the test images: 9.48% & Test Loss: 2.752604739665985
# Train Log:Epoch: 113, Step [1/60000], TrainLoss: 1.5939
# Train Log:Epoch: 113, Step [501/60000], TrainLoss: 1.6632
# Accuracy of the network on the test images: 10.41% & Test Loss: 2.748377749919891
# Train Log:Epoch: 114, Step [1/60000], TrainLoss: 1.6669
# Train Log:Epoch: 114, Step [501/60000], TrainLoss: 1.5924
# Accuracy of the network on the test images: 9.06% & Test Loss: 2.7825454926490782
# Train Log:Epoch: 115, Step [1/60000], TrainLoss: 1.5419
# Train Log:Epoch: 115, Step [501/60000], TrainLoss: 1.5997
# Accuracy of the network on the test images: 9.06% & Test Loss: 2.782445635795593
# Train Log:Epoch: 116, Step [1/60000], TrainLoss: 1.5372
# Train Log:Epoch: 116, Step [501/60000], TrainLoss: 1.6241
# Accuracy of the network on the test images: 9.44% & Test Loss: 2.771802234649658
# Train Log:Epoch: 117, Step [1/60000], TrainLoss: 1.5565
# Train Log:Epoch: 117, Step [501/60000], TrainLoss: 1.4561
# Accuracy of the network on the test images: 10.14% & Test Loss: 2.76814427614212
# Train Log:Epoch: 118, Step [1/60000], TrainLoss: 1.4940
# Train Log:Epoch: 118, Step [501/60000], TrainLoss: 1.6372
# Accuracy of the network on the test images: 9.93% & Test Loss: 2.7812753653526308
# Train Log:Epoch: 119, Step [1/60000], TrainLoss: 1.6872
# Train Log:Epoch: 119, Step [501/60000], TrainLoss: 1.5392
# Accuracy of the network on the test images: 9.94% & Test Loss: 2.8082261228561403
# Train Log:Epoch: 120, Step [1/60000], TrainLoss: 1.5333
# Train Log:Epoch: 120, Step [501/60000], TrainLoss: 1.5932
# Accuracy of the network on the test images: 11.09% & Test Loss: 2.7998625445365906
# Train Log:Epoch: 121, Step [1/60000], TrainLoss: 1.5035
# Train Log:Epoch: 121, Step [501/60000], TrainLoss: 1.5433
# Accuracy of the network on the test images: 9.46% & Test Loss: 2.8047188687324525
# Train Log:Epoch: 122, Step [1/60000], TrainLoss: 1.6054
# Train Log:Epoch: 122, Step [501/60000], TrainLoss: 1.6136
# Accuracy of the network on the test images: 10.35% & Test Loss: 2.8008641028404235
# Train Log:Epoch: 123, Step [1/60000], TrainLoss: 1.5370
# Train Log:Epoch: 123, Step [501/60000], TrainLoss: 1.5196
# Accuracy of the network on the test images: 9.42% & Test Loss: 2.8202030277252197
# Train Log:Epoch: 124, Step [1/60000], TrainLoss: 1.5701
# Train Log:Epoch: 124, Step [501/60000], TrainLoss: 1.6041
# Accuracy of the network on the test images: 11.2% & Test Loss: 2.792473707199097
# Train Log:Epoch: 125, Step [1/60000], TrainLoss: 1.5079
# Train Log:Epoch: 125, Step [501/60000], TrainLoss: 1.4686
# Accuracy of the network on the test images: 10.2% & Test Loss: 2.813567419052124
# Train Log:Epoch: 126, Step [1/60000], TrainLoss: 1.5286
# Train Log:Epoch: 126, Step [501/60000], TrainLoss: 1.3562
# Accuracy of the network on the test images: 10.92% & Test Loss: 2.764364631175995
# Train Log:Epoch: 127, Step [1/60000], TrainLoss: 1.3841
# Train Log:Epoch: 127, Step [501/60000], TrainLoss: 1.5046
# Accuracy of the network on the test images: 9.72% & Test Loss: 2.8248323941230775
# Train Log:Epoch: 128, Step [1/60000], TrainLoss: 1.5385
# Train Log:Epoch: 128, Step [501/60000], TrainLoss: 1.5178
# Accuracy of the network on the test images: 9.6% & Test Loss: 2.8501063489913943
# Train Log:Epoch: 129, Step [1/60000], TrainLoss: 1.5972
# Train Log:Epoch: 129, Step [501/60000], TrainLoss: 1.5354
# Accuracy of the network on the test images: 9.23% & Test Loss: 2.8619539093971254
# Train Log:Epoch: 130, Step [1/60000], TrainLoss: 1.5460
# Train Log:Epoch: 130, Step [501/60000], TrainLoss: 1.4732
# Accuracy of the network on the test images: 9.86% & Test Loss: 2.849334409236908
# Train Log:Epoch: 131, Step [1/60000], TrainLoss: 1.5132
# Train Log:Epoch: 131, Step [501/60000], TrainLoss: 1.6658
# Accuracy of the network on the test images: 10.42% & Test Loss: 2.83593252658844
# Train Log:Epoch: 132, Step [1/60000], TrainLoss: 1.4441
# Train Log:Epoch: 132, Step [501/60000], TrainLoss: 1.7126
# Accuracy of the network on the test images: 9.26% & Test Loss: 2.87498010635376
# Train Log:Epoch: 133, Step [1/60000], TrainLoss: 1.5444
# Train Log:Epoch: 133, Step [501/60000], TrainLoss: 1.4078
# Accuracy of the network on the test images: 9.63% & Test Loss: 2.8517735815048217
# Train Log:Epoch: 134, Step [1/60000], TrainLoss: 1.4266
# Train Log:Epoch: 134, Step [501/60000], TrainLoss: 1.5909
# Accuracy of the network on the test images: 9.88% & Test Loss: 2.8744108057022095
# Train Log:Epoch: 135, Step [1/60000], TrainLoss: 1.5128
# Train Log:Epoch: 135, Step [501/60000], TrainLoss: 1.6144
# Accuracy of the network on the test images: 10.48% & Test Loss: 2.8945443344116213
# Train Log:Epoch: 136, Step [1/60000], TrainLoss: 1.4127
# Train Log:Epoch: 136, Step [501/60000], TrainLoss: 1.3083
# Accuracy of the network on the test images: 8.77% & Test Loss: 2.932108404636383
# Train Log:Epoch: 137, Step [1/60000], TrainLoss: 1.3689
# Train Log:Epoch: 137, Step [501/60000], TrainLoss: 1.6072
# Accuracy of the network on the test images: 10.47% & Test Loss: 2.853153357505798
# Train Log:Epoch: 138, Step [1/60000], TrainLoss: 1.4084
# Train Log:Epoch: 138, Step [501/60000], TrainLoss: 1.4326
# Accuracy of the network on the test images: 10.11% & Test Loss: 2.8612735772132876
# Train Log:Epoch: 139, Step [1/60000], TrainLoss: 1.4379
# Train Log:Epoch: 139, Step [501/60000], TrainLoss: 1.4210
# Accuracy of the network on the test images: 9.58% & Test Loss: 2.933631601333618
# Train Log:Epoch: 140, Step [1/60000], TrainLoss: 1.3582
# Train Log:Epoch: 140, Step [501/60000], TrainLoss: 1.4640
# Accuracy of the network on the test images: 10.39% & Test Loss: 2.876822316646576
# Train Log:Epoch: 141, Step [1/60000], TrainLoss: 1.3690
# Train Log:Epoch: 141, Step [501/60000], TrainLoss: 1.5181
# Accuracy of the network on the test images: 9.1% & Test Loss: 2.937735204696655
# Train Log:Epoch: 142, Step [1/60000], TrainLoss: 1.4597
# Train Log:Epoch: 142, Step [501/60000], TrainLoss: 1.3034
# Accuracy of the network on the test images: 8.53% & Test Loss: 2.9581973338127137
# Train Log:Epoch: 143, Step [1/60000], TrainLoss: 1.3229
# Train Log:Epoch: 143, Step [501/60000], TrainLoss: 1.4896
# Accuracy of the network on the test images: 9.97% & Test Loss: 2.904922835826874
# Train Log:Epoch: 144, Step [1/60000], TrainLoss: 1.3905
# Train Log:Epoch: 144, Step [501/60000], TrainLoss: 1.2974
# Accuracy of the network on the test images: 9.82% & Test Loss: 2.9104620957374574
# Train Log:Epoch: 145, Step [1/60000], TrainLoss: 1.4694
# Train Log:Epoch: 145, Step [501/60000], TrainLoss: 1.3922
# Accuracy of the network on the test images: 9.75% & Test Loss: 2.9277862811088564
# Train Log:Epoch: 146, Step [1/60000], TrainLoss: 1.4391
# Train Log:Epoch: 146, Step [501/60000], TrainLoss: 1.3836
# Accuracy of the network on the test images: 9.71% & Test Loss: 2.9347129106521606
# Train Log:Epoch: 147, Step [1/60000], TrainLoss: 1.3485
# Train Log:Epoch: 147, Step [501/60000], TrainLoss: 1.3295
# Accuracy of the network on the test images: 10.39% & Test Loss: 2.920118200778961
# Train Log:Epoch: 148, Step [1/60000], TrainLoss: 1.4135
# Train Log:Epoch: 148, Step [501/60000], TrainLoss: 1.3129
# Accuracy of the network on the test images: 9.5% & Test Loss: 2.9432343292236327
# Train Log:Epoch: 149, Step [1/60000], TrainLoss: 1.3277
# Train Log:Epoch: 149, Step [501/60000], TrainLoss: 1.4504
# Accuracy of the network on the test images: 9.8% & Test Loss: 2.9659834051132203
# Train Log:Epoch: 150, Step [1/60000], TrainLoss: 1.3683
# Train Log:Epoch: 150, Step [501/60000], TrainLoss: 1.3690
# Accuracy of the network on the test images: 10.77% & Test Loss: 2.9350874519348142
# Train Log:Epoch: 151, Step [1/60000], TrainLoss: 1.3614
# Train Log:Epoch: 151, Step [501/60000], TrainLoss: 1.3915
# Accuracy of the network on the test images: 9.63% & Test Loss: 2.9913207411766054
# Train Log:Epoch: 152, Step [1/60000], TrainLoss: 1.4477
# Train Log:Epoch: 152, Step [501/60000], TrainLoss: 1.4381
# Accuracy of the network on the test images: 10.1% & Test Loss: 2.9358490204811094
# Train Log:Epoch: 153, Step [1/60000], TrainLoss: 1.2973
# Train Log:Epoch: 153, Step [501/60000], TrainLoss: 1.2561
# Accuracy of the network on the test images: 9.72% & Test Loss: 3.003197259902954
# Train Log:Epoch: 154, Step [1/60000], TrainLoss: 1.3520
# Train Log:Epoch: 154, Step [501/60000], TrainLoss: 1.2851
# Accuracy of the network on the test images: 9.43% & Test Loss: 2.998433701992035
# Train Log:Epoch: 155, Step [1/60000], TrainLoss: 1.2765
# Train Log:Epoch: 155, Step [501/60000], TrainLoss: 1.4010
# Accuracy of the network on the test images: 9.83% & Test Loss: 2.9519173860549928
# Train Log:Epoch: 156, Step [1/60000], TrainLoss: 1.3502
# Train Log:Epoch: 156, Step [501/60000], TrainLoss: 1.2318
# Accuracy of the network on the test images: 10.3% & Test Loss: 2.9900656151771545
# Train Log:Epoch: 157, Step [1/60000], TrainLoss: 1.3206
# Train Log:Epoch: 157, Step [501/60000], TrainLoss: 1.2781
# Accuracy of the network on the test images: 9.94% & Test Loss: 2.9713744163513183
# Train Log:Epoch: 158, Step [1/60000], TrainLoss: 1.3463
# Train Log:Epoch: 158, Step [501/60000], TrainLoss: 1.4575
# Accuracy of the network on the test images: 9.17% & Test Loss: 3.023450183868408
# Train Log:Epoch: 159, Step [1/60000], TrainLoss: 1.3622
# Train Log:Epoch: 159, Step [501/60000], TrainLoss: 1.3792
# Accuracy of the network on the test images: 9.47% & Test Loss: 3.0051718664169313
# Train Log:Epoch: 160, Step [1/60000], TrainLoss: 1.0777
# Train Log:Epoch: 160, Step [501/60000], TrainLoss: 1.4886
# Accuracy of the network on the test images: 9.8% & Test Loss: 3.0281556105613707
# Train Log:Epoch: 161, Step [1/60000], TrainLoss: 1.3371
# Train Log:Epoch: 161, Step [501/60000], TrainLoss: 1.3120
# Accuracy of the network on the test images: 9.4% & Test Loss: 3.0176165890693665
# Train Log:Epoch: 162, Step [1/60000], TrainLoss: 1.2326
# Train Log:Epoch: 162, Step [501/60000], TrainLoss: 1.3177
# Accuracy of the network on the test images: 9.77% & Test Loss: 3.058568825721741
# Train Log:Epoch: 163, Step [1/60000], TrainLoss: 1.3681
# Train Log:Epoch: 163, Step [501/60000], TrainLoss: 1.3175
# Accuracy of the network on the test images: 9.74% & Test Loss: 3.042832872867584
# Train Log:Epoch: 164, Step [1/60000], TrainLoss: 1.1143
# Train Log:Epoch: 164, Step [501/60000], TrainLoss: 1.3779
# Accuracy of the network on the test images: 9.1% & Test Loss: 3.055662889480591
# Train Log:Epoch: 165, Step [1/60000], TrainLoss: 1.2096
# Train Log:Epoch: 165, Step [501/60000], TrainLoss: 1.3204
# Accuracy of the network on the test images: 10.18% & Test Loss: 3.010946626663208
# Train Log:Epoch: 166, Step [1/60000], TrainLoss: 1.2292
# Train Log:Epoch: 166, Step [501/60000], TrainLoss: 1.4445
# Accuracy of the network on the test images: 10.06% & Test Loss: 3.019784297943115
# Train Log:Epoch: 167, Step [1/60000], TrainLoss: 1.1696
# Train Log:Epoch: 167, Step [501/60000], TrainLoss: 1.3331
# Accuracy of the network on the test images: 8.77% & Test Loss: 3.0956781339645385
# Train Log:Epoch: 168, Step [1/60000], TrainLoss: 1.2639
# Train Log:Epoch: 168, Step [501/60000], TrainLoss: 1.1880
# Accuracy of the network on the test images: 8.87% & Test Loss: 3.1172200989723207
# Train Log:Epoch: 169, Step [1/60000], TrainLoss: 1.4307
# Train Log:Epoch: 169, Step [501/60000], TrainLoss: 1.3549
# Accuracy of the network on the test images: 9.76% & Test Loss: 3.09264310836792
# Train Log:Epoch: 170, Step [1/60000], TrainLoss: 1.3285
# Train Log:Epoch: 170, Step [501/60000], TrainLoss: 1.2085
# Accuracy of the network on the test images: 9.84% & Test Loss: 3.047700250148773
# Train Log:Epoch: 171, Step [1/60000], TrainLoss: 1.1045
# Train Log:Epoch: 171, Step [501/60000], TrainLoss: 1.2865
# Accuracy of the network on the test images: 9.54% & Test Loss: 3.0773417258262636
# Train Log:Epoch: 172, Step [1/60000], TrainLoss: 1.3673
# Train Log:Epoch: 172, Step [501/60000], TrainLoss: 1.3911
# Accuracy of the network on the test images: 10.04% & Test Loss: 3.0554507040977477
# Train Log:Epoch: 173, Step [1/60000], TrainLoss: 1.1997
# Train Log:Epoch: 173, Step [501/60000], TrainLoss: 1.1960
# Accuracy of the network on the test images: 9.74% & Test Loss: 3.086329004764557
# Train Log:Epoch: 174, Step [1/60000], TrainLoss: 1.3051
# Train Log:Epoch: 174, Step [501/60000], TrainLoss: 1.3793
# Accuracy of the network on the test images: 10.07% & Test Loss: 3.0821950125694273
# Train Log:Epoch: 175, Step [1/60000], TrainLoss: 1.4171
# Train Log:Epoch: 175, Step [501/60000], TrainLoss: 1.2657
# Accuracy of the network on the test images: 9.1% & Test Loss: 3.1415900492668154
# Train Log:Epoch: 176, Step [1/60000], TrainLoss: 1.2722
# Train Log:Epoch: 176, Step [501/60000], TrainLoss: 1.1355
# Accuracy of the network on the test images: 8.89% & Test Loss: 3.181384506225586
# Train Log:Epoch: 177, Step [1/60000], TrainLoss: 1.2417
# Train Log:Epoch: 177, Step [501/60000], TrainLoss: 1.3979
# Accuracy of the network on the test images: 8.9% & Test Loss: 3.142765905857086
# Train Log:Epoch: 178, Step [1/60000], TrainLoss: 1.2107
# Train Log:Epoch: 178, Step [501/60000], TrainLoss: 1.3282
# Accuracy of the network on the test images: 8.97% & Test Loss: 3.141299455165863
# Train Log:Epoch: 179, Step [1/60000], TrainLoss: 1.2377
# Train Log:Epoch: 179, Step [501/60000], TrainLoss: 1.3258
# Accuracy of the network on the test images: 9.76% & Test Loss: 3.1188834953308104
# Train Log:Epoch: 180, Step [1/60000], TrainLoss: 1.2042
# Train Log:Epoch: 180, Step [501/60000], TrainLoss: 1.1722
# Accuracy of the network on the test images: 9.12% & Test Loss: 3.1964363408088685
# Train Log:Epoch: 181, Step [1/60000], TrainLoss: 1.1638
# Train Log:Epoch: 181, Step [501/60000], TrainLoss: 1.2229
# Accuracy of the network on the test images: 8.76% & Test Loss: 3.1895862889289854
# Train Log:Epoch: 182, Step [1/60000], TrainLoss: 1.2251
# Train Log:Epoch: 182, Step [501/60000], TrainLoss: 1.5107
# Accuracy of the network on the test images: 9.45% & Test Loss: 3.1634120965003967
# Train Log:Epoch: 183, Step [1/60000], TrainLoss: 1.2162
# Train Log:Epoch: 183, Step [501/60000], TrainLoss: 1.3981
# Accuracy of the network on the test images: 9.07% & Test Loss: 3.1437400007247924
# Train Log:Epoch: 184, Step [1/60000], TrainLoss: 1.2587
# Train Log:Epoch: 184, Step [501/60000], TrainLoss: 1.2587
# Accuracy of the network on the test images: 10.79% & Test Loss: 3.1183398485183718
# Train Log:Epoch: 185, Step [1/60000], TrainLoss: 1.2024
# Train Log:Epoch: 185, Step [501/60000], TrainLoss: 1.2118
# Accuracy of the network on the test images: 10.17% & Test Loss: 3.212641317844391
# Train Log:Epoch: 186, Step [1/60000], TrainLoss: 1.1858
# Train Log:Epoch: 186, Step [501/60000], TrainLoss: 1.1491
# Accuracy of the network on the test images: 9.58% & Test Loss: 3.1726350665092466
# Train Log:Epoch: 187, Step [1/60000], TrainLoss: 1.1923
# Train Log:Epoch: 187, Step [501/60000], TrainLoss: 1.3652
# Accuracy of the network on the test images: 10.2% & Test Loss: 3.1425447034835816
# Train Log:Epoch: 188, Step [1/60000], TrainLoss: 1.2331
# Train Log:Epoch: 188, Step [501/60000], TrainLoss: 1.3694
# Accuracy of the network on the test images: 8.67% & Test Loss: 3.2564387416839597
# Train Log:Epoch: 189, Step [1/60000], TrainLoss: 1.2132
# Train Log:Epoch: 189, Step [501/60000], TrainLoss: 1.2129
# Accuracy of the network on the test images: 8.17% & Test Loss: 3.2619591999053954
# Train Log:Epoch: 190, Step [1/60000], TrainLoss: 1.3198
# Train Log:Epoch: 190, Step [501/60000], TrainLoss: 1.2666
# Accuracy of the network on the test images: 9.66% & Test Loss: 3.188334403038025
# Train Log:Epoch: 191, Step [1/60000], TrainLoss: 1.2137
# Train Log:Epoch: 191, Step [501/60000], TrainLoss: 1.2370
# Accuracy of the network on the test images: 8.97% & Test Loss: 3.221221272945404
# Train Log:Epoch: 192, Step [1/60000], TrainLoss: 1.1105
# Train Log:Epoch: 192, Step [501/60000], TrainLoss: 1.1750
# Accuracy of the network on the test images: 9.51% & Test Loss: 3.2261054134368896
# Train Log:Epoch: 193, Step [1/60000], TrainLoss: 1.0564
# Train Log:Epoch: 193, Step [501/60000], TrainLoss: 1.0862
# Accuracy of the network on the test images: 9.07% & Test Loss: 3.250973365306854
# Train Log:Epoch: 194, Step [1/60000], TrainLoss: 1.2447
# Train Log:Epoch: 194, Step [501/60000], TrainLoss: 1.2358
# Accuracy of the network on the test images: 10.0% & Test Loss: 3.2133726191520693
# Train Log:Epoch: 195, Step [1/60000], TrainLoss: 1.0740
# Train Log:Epoch: 195, Step [501/60000], TrainLoss: 1.2032
# Accuracy of the network on the test images: 9.35% & Test Loss: 3.244818911552429
# Train Log:Epoch: 196, Step [1/60000], TrainLoss: 1.2224
# Train Log:Epoch: 196, Step [501/60000], TrainLoss: 1.0978
# Accuracy of the network on the test images: 9.01% & Test Loss: 3.2571486926078794
# Train Log:Epoch: 197, Step [1/60000], TrainLoss: 1.1189
# Train Log:Epoch: 197, Step [501/60000], TrainLoss: 1.2561
# Accuracy of the network on the test images: 9.0% & Test Loss: 3.281134474277496
# Train Log:Epoch: 198, Step [1/60000], TrainLoss: 1.1811
# Train Log:Epoch: 198, Step [501/60000], TrainLoss: 1.1464
# Accuracy of the network on the test images: 8.78% & Test Loss: 3.2804847717285157
# Train Log:Epoch: 199, Step [1/60000], TrainLoss: 1.0591
# Train Log:Epoch: 199, Step [501/60000], TrainLoss: 1.1214
# Accuracy of the network on the test images: 10.21% & Test Loss: 3.231389138698578
# Train Log:Epoch: 200, Step [1/60000], TrainLoss: 1.0260
# Train Log:Epoch: 200, Step [501/60000], TrainLoss: 1.2868
# Accuracy of the network on the test images: 9.3% & Test Loss: 3.27152104139328
# Train Log:Epoch: 201, Step [1/60000], TrainLoss: 1.1956
# Train Log:Epoch: 201, Step [501/60000], TrainLoss: 1.2882
# Accuracy of the network on the test images: 9.05% & Test Loss: 3.2644078159332275
# Train Log:Epoch: 202, Step [1/60000], TrainLoss: 1.1065
# Train Log:Epoch: 202, Step [501/60000], TrainLoss: 1.2678
# Accuracy of the network on the test images: 9.44% & Test Loss: 3.309474165439606
# Train Log:Epoch: 203, Step [1/60000], TrainLoss: 1.1536
# Train Log:Epoch: 203, Step [501/60000], TrainLoss: 1.0315
# Accuracy of the network on the test images: 9.77% & Test Loss: 3.243781342506409
# Train Log:Epoch: 204, Step [1/60000], TrainLoss: 1.0836
# Train Log:Epoch: 204, Step [501/60000], TrainLoss: 1.1498
# Accuracy of the network on the test images: 8.93% & Test Loss: 3.304120774269104
# Train Log:Epoch: 205, Step [1/60000], TrainLoss: 1.0914
# Train Log:Epoch: 205, Step [501/60000], TrainLoss: 1.0803
# Accuracy of the network on the test images: 9.49% & Test Loss: 3.2705854892730715
# Train Log:Epoch: 206, Step [1/60000], TrainLoss: 1.1550
# Train Log:Epoch: 206, Step [501/60000], TrainLoss: 1.0381
# Accuracy of the network on the test images: 8.67% & Test Loss: 3.342225396633148
# Train Log:Epoch: 207, Step [1/60000], TrainLoss: 1.0853
# Train Log:Epoch: 207, Step [501/60000], TrainLoss: 1.0132
# Accuracy of the network on the test images: 8.69% & Test Loss: 3.3258084297180175
# Train Log:Epoch: 208, Step [1/60000], TrainLoss: 1.0476
# Train Log:Epoch: 208, Step [501/60000], TrainLoss: 1.0608
# Accuracy of the network on the test images: 9.55% & Test Loss: 3.2885487151145933
# Train Log:Epoch: 209, Step [1/60000], TrainLoss: 1.0204
# Train Log:Epoch: 209, Step [501/60000], TrainLoss: 1.1100
# Accuracy of the network on the test images: 9.52% & Test Loss: 3.3152071261405944
# Train Log:Epoch: 210, Step [1/60000], TrainLoss: 1.0915
# Train Log:Epoch: 210, Step [501/60000], TrainLoss: 1.0755
# Accuracy of the network on the test images: 8.84% & Test Loss: 3.428454787731171
# Train Log:Epoch: 211, Step [1/60000], TrainLoss: 1.1439
# Train Log:Epoch: 211, Step [501/60000], TrainLoss: 1.1310
# Accuracy of the network on the test images: 8.19% & Test Loss: 3.4461086320877077
# Train Log:Epoch: 212, Step [1/60000], TrainLoss: 1.1410
# Train Log:Epoch: 212, Step [501/60000], TrainLoss: 1.1715
# Accuracy of the network on the test images: 9.72% & Test Loss: 3.320165207386017
# Train Log:Epoch: 213, Step [1/60000], TrainLoss: 1.1146
# Train Log:Epoch: 213, Step [501/60000], TrainLoss: 1.0858
# Accuracy of the network on the test images: 8.97% & Test Loss: 3.3716666197776792
# Train Log:Epoch: 214, Step [1/60000], TrainLoss: 1.1658
# Train Log:Epoch: 214, Step [501/60000], TrainLoss: 1.1347
# Accuracy of the network on the test images: 9.86% & Test Loss: 3.33381272315979
# Train Log:Epoch: 215, Step [1/60000], TrainLoss: 1.0570
# Train Log:Epoch: 215, Step [501/60000], TrainLoss: 1.1263
# Accuracy of the network on the test images: 9.47% & Test Loss: 3.3380951499938964
# Train Log:Epoch: 216, Step [1/60000], TrainLoss: 1.0510
# Train Log:Epoch: 216, Step [501/60000], TrainLoss: 1.0651
# Accuracy of the network on the test images: 8.58% & Test Loss: 3.426766822338104
# Train Log:Epoch: 217, Step [1/60000], TrainLoss: 1.1386
# Train Log:Epoch: 217, Step [501/60000], TrainLoss: 1.0149
# Accuracy of the network on the test images: 9.19% & Test Loss: 3.3816582894325258
# Train Log:Epoch: 218, Step [1/60000], TrainLoss: 1.0523
# Train Log:Epoch: 218, Step [501/60000], TrainLoss: 1.1073
# Accuracy of the network on the test images: 9.61% & Test Loss: 3.3623064804077147
# Train Log:Epoch: 219, Step [1/60000], TrainLoss: 1.0869
# Train Log:Epoch: 219, Step [501/60000], TrainLoss: 1.1266
# Accuracy of the network on the test images: 10.04% & Test Loss: 3.3624291682243346
# Train Log:Epoch: 220, Step [1/60000], TrainLoss: 1.0927
# Train Log:Epoch: 220, Step [501/60000], TrainLoss: 1.2155
# Accuracy of the network on the test images: 9.19% & Test Loss: 3.3744473886489867
# Train Log:Epoch: 221, Step [1/60000], TrainLoss: 1.1571
# Train Log:Epoch: 221, Step [501/60000], TrainLoss: 1.0498
# Accuracy of the network on the test images: 9.36% & Test Loss: 3.417157995700836
# Train Log:Epoch: 222, Step [1/60000], TrainLoss: 1.2665
# Train Log:Epoch: 222, Step [501/60000], TrainLoss: 1.2016
# Accuracy of the network on the test images: 9.61% & Test Loss: 3.35592613697052
# Train Log:Epoch: 223, Step [1/60000], TrainLoss: 1.0744
# Train Log:Epoch: 223, Step [501/60000], TrainLoss: 1.0804
# Accuracy of the network on the test images: 9.4% & Test Loss: 3.4245922231674193
# Train Log:Epoch: 224, Step [1/60000], TrainLoss: 1.1540
# Train Log:Epoch: 224, Step [501/60000], TrainLoss: 1.1168
# Accuracy of the network on the test images: 9.02% & Test Loss: 3.4197372603416443
# Train Log:Epoch: 225, Step [1/60000], TrainLoss: 1.1797
# Train Log:Epoch: 225, Step [501/60000], TrainLoss: 1.0037
# Accuracy of the network on the test images: 9.06% & Test Loss: 3.4937739157676697
# Train Log:Epoch: 226, Step [1/60000], TrainLoss: 0.8478
# Train Log:Epoch: 226, Step [501/60000], TrainLoss: 1.0546
# Accuracy of the network on the test images: 9.14% & Test Loss: 3.4511196398735047
# Train Log:Epoch: 227, Step [1/60000], TrainLoss: 1.0036
# Train Log:Epoch: 227, Step [501/60000], TrainLoss: 1.0630
# Accuracy of the network on the test images: 10.27% & Test Loss: 3.3817530703544616
# Train Log:Epoch: 228, Step [1/60000], TrainLoss: 0.9652
# Train Log:Epoch: 228, Step [501/60000], TrainLoss: 1.1817
# Accuracy of the network on the test images: 8.67% & Test Loss: 3.4393434929847717
# Train Log:Epoch: 229, Step [1/60000], TrainLoss: 0.9679
# Train Log:Epoch: 229, Step [501/60000], TrainLoss: 1.0686
# Accuracy of the network on the test images: 9.46% & Test Loss: 3.4361718320846557
# Train Log:Epoch: 230, Step [1/60000], TrainLoss: 0.9013
# Train Log:Epoch: 230, Step [501/60000], TrainLoss: 1.2196
# Accuracy of the network on the test images: 9.29% & Test Loss: 3.496797459125519
# Train Log:Epoch: 231, Step [1/60000], TrainLoss: 1.0258
# Train Log:Epoch: 231, Step [501/60000], TrainLoss: 1.0310
# Accuracy of the network on the test images: 8.32% & Test Loss: 3.54285404920578
# Train Log:Epoch: 232, Step [1/60000], TrainLoss: 1.0386
# Train Log:Epoch: 232, Step [501/60000], TrainLoss: 1.0742
# Accuracy of the network on the test images: 8.85% & Test Loss: 3.4785690355300902
# Train Log:Epoch: 233, Step [1/60000], TrainLoss: 1.0293
# Train Log:Epoch: 233, Step [501/60000], TrainLoss: 1.0182
# Accuracy of the network on the test images: 9.95% & Test Loss: 3.3988227605819703
# Train Log:Epoch: 234, Step [1/60000], TrainLoss: 0.9249
# Train Log:Epoch: 234, Step [501/60000], TrainLoss: 1.0505
# Accuracy of the network on the test images: 9.14% & Test Loss: 3.494982614517212
# Train Log:Epoch: 235, Step [1/60000], TrainLoss: 1.0154
# Train Log:Epoch: 235, Step [501/60000], TrainLoss: 1.1056
# Accuracy of the network on the test images: 8.78% & Test Loss: 3.519192361831665
# Train Log:Epoch: 236, Step [1/60000], TrainLoss: 1.0789
# Train Log:Epoch: 236, Step [501/60000], TrainLoss: 1.1317
# Accuracy of the network on the test images: 9.33% & Test Loss: 3.518452699184418
# Train Log:Epoch: 237, Step [1/60000], TrainLoss: 1.0491
# Train Log:Epoch: 237, Step [501/60000], TrainLoss: 1.0116
# Accuracy of the network on the test images: 9.5% & Test Loss: 3.524710865020752
# Train Log:Epoch: 238, Step [1/60000], TrainLoss: 0.8956
# Train Log:Epoch: 238, Step [501/60000], TrainLoss: 1.0109
# Accuracy of the network on the test images: 9.08% & Test Loss: 3.56570130109787
# Train Log:Epoch: 239, Step [1/60000], TrainLoss: 0.9374
# Train Log:Epoch: 239, Step [501/60000], TrainLoss: 1.1563
# Accuracy of the network on the test images: 9.91% & Test Loss: 3.440223226547241
# Train Log:Epoch: 240, Step [1/60000], TrainLoss: 0.9574
# Train Log:Epoch: 240, Step [501/60000], TrainLoss: 0.9888
# Accuracy of the network on the test images: 9.2% & Test Loss: 3.530193336009979
# Train Log:Epoch: 241, Step [1/60000], TrainLoss: 0.9597
# Train Log:Epoch: 241, Step [501/60000], TrainLoss: 0.9657
# Accuracy of the network on the test images: 9.51% & Test Loss: 3.5300938272476197
# Train Log:Epoch: 242, Step [1/60000], TrainLoss: 0.9192
# Train Log:Epoch: 242, Step [501/60000], TrainLoss: 1.0487
# Accuracy of the network on the test images: 8.76% & Test Loss: 3.5722980880737305
# Train Log:Epoch: 243, Step [1/60000], TrainLoss: 0.8603
# Train Log:Epoch: 243, Step [501/60000], TrainLoss: 1.1174
# Accuracy of the network on the test images: 9.02% & Test Loss: 3.6168981313705446
# Train Log:Epoch: 244, Step [1/60000], TrainLoss: 1.1556
# Train Log:Epoch: 244, Step [501/60000], TrainLoss: 1.0278
# Accuracy of the network on the test images: 9.02% & Test Loss: 3.5520079708099366
# Train Log:Epoch: 245, Step [1/60000], TrainLoss: 1.0412
# Train Log:Epoch: 245, Step [501/60000], TrainLoss: 1.0829
# Accuracy of the network on the test images: 9.75% & Test Loss: 3.562526729106903
# Train Log:Epoch: 246, Step [1/60000], TrainLoss: 0.8338
# Train Log:Epoch: 246, Step [501/60000], TrainLoss: 0.9861
# Accuracy of the network on the test images: 8.72% & Test Loss: 3.582478380203247
# Train Log:Epoch: 247, Step [1/60000], TrainLoss: 0.9110
# Train Log:Epoch: 247, Step [501/60000], TrainLoss: 0.9374
# Accuracy of the network on the test images: 8.74% & Test Loss: 3.631249098777771
# Train Log:Epoch: 248, Step [1/60000], TrainLoss: 0.9344
# Train Log:Epoch: 248, Step [501/60000], TrainLoss: 0.9685
# Accuracy of the network on the test images: 8.98% & Test Loss: 3.597493977546692
# Train Log:Epoch: 249, Step [1/60000], TrainLoss: 0.9569
# Train Log:Epoch: 249, Step [501/60000], TrainLoss: 0.9297
# Accuracy of the network on the test images: 8.93% & Test Loss: 3.5756553769111634
# Train Log:Epoch: 250, Step [1/60000], TrainLoss: 0.8590
# Train Log:Epoch: 250, Step [501/60000], TrainLoss: 1.0933
# Accuracy of the network on the test images: 8.69% & Test Loss: 3.6168594050407408
# Train Log:Epoch: 251, Step [1/60000], TrainLoss: 1.0257
# Train Log:Epoch: 251, Step [501/60000], TrainLoss: 1.0346
# Accuracy of the network on the test images: 8.84% & Test Loss: 3.6411402320861814
# Train Log:Epoch: 252, Step [1/60000], TrainLoss: 0.9992
# Train Log:Epoch: 252, Step [501/60000], TrainLoss: 0.9254
# Accuracy of the network on the test images: 9.56% & Test Loss: 3.5784977149963377
# Train Log:Epoch: 253, Step [1/60000], TrainLoss: 1.0167
# Train Log:Epoch: 253, Step [501/60000], TrainLoss: 0.9332
# Accuracy of the network on the test images: 9.54% & Test Loss: 3.6087247562408447
# Train Log:Epoch: 254, Step [1/60000], TrainLoss: 1.0755
# Train Log:Epoch: 254, Step [501/60000], TrainLoss: 1.1032
